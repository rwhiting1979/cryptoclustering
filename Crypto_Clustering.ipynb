# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_market_data)

# %%
# Create a DataFrame with the scaled data
df_market_scaled = pd.DataFrame(scaled_data, columns=df_market_data.columns)

# Copy the crypto names from the original data
df_market_scaled['coin_id'] = df_market_data.index

# Set the coinid column as index
df_market_scaled.set_index('coin_id', inplace=True)

# Display sample data
df_market_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia_list = []

# Create a for loop to compute the inertia with each possible value of k
for k in k_values:

# Inside the loop:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=0)

    # 2. Fit the model to the data using `df_market_data_scaled`
    kmeans.fit(df_market_scaled)

    # 3. Append the model.inertia_ to the inertia list
    inertia_list.append(kmeans.inertia_)
# Out:
# C:\Users\rwhit\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   "KMeans is known to have a memory leak on Windows "

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': k_values, 'inertia': inertia_list}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow1 = pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
df_elbow1.hvplot.line(x='k', y='inertia', title='Elbow Curve', xticks=k_values)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
k_value = 4
kmeans = KMeans(n_clusters=k_value, random_state=0)

# %%
# Fit the K-Means model using the scaled data
kmeans.fit(df_market_scaled)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
clusters = kmeans.predict(df_market_scaled)

# Print the resulting array of cluster values.
print(clusters)
# Out:
# [0 0 3 3 0 0 0 0 0 3 3 3 3 0 3 0 3 3 0 3 3 0 3 3 3 3 3 3 0 3 3 3 1 0 3 3 2
#  3 3 3 3]

# %%
# Create a copy of the DataFrame
df_market_clustered = df_market_scaled.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
df_market_clustered['cluster'] = clusters

# Display sample data
df_market_clustered
# Out:
#                       price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                                  0.508529                    0.493193
# ethereum                                 0.185446                    0.934445
# tether                                   0.021774                   -0.706337
# ripple                                  -0.040764                   -0.810928
# bitcoin-cash                             1.193036                    2.000959
# binancecoin                              0.891871                    1.327295
# chainlink                                0.011397                    2.572251
# cardano                                  0.102530                    1.508001
# litecoin                                 0.077497                    0.334297
# bitcoin-cash-sv                          0.448952                   -0.190684
# crypto-com-chain                         0.331280                   -1.614844
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
scatter_plot1 = df_market_clustered.hvplot.scatter(
    x='price_change_percentage_24h', 
    y='price_change_percentage_7d', 
    by='cluster', 
    hover_cols=['coin_id'], 
    title='Cryptocurrency Clusters'
)

scatter_plot1
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
pca_data = pca.fit_transform(df_market_scaled)

df_pca = pd.DataFrame(
    data=pca_data, 
    columns=['PC 1', 'PC 2', 'PC 3'],
    index=df_market_scaled.index
)

# View the first five rows of the DataFrame. 
df_pca.head()
# Out:
#                   PC 1      PC 2      PC 3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
pca.explained_variance_ratio_
# Out:
# array([0.3719856 , 0.34700813, 0.17603793])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** The total explained variance of the three principal components is approximately 0.895, or 89.5%. This indicates that these three principal components together capture about 89.5% of the variance in your dataset.

# %%
# Create a new DataFrame with the PCA data.
df_pca_with_names = df_pca.copy()

# Creating a DataFrame with the PCA data

# Copy the crypto names from the original data
df_pca_with_names['coin_id'] = df_pca.index

# Set the coinid column as index
df_pca_with_names.set_index('coin_id', inplace=True)

# Display sample data
df_pca_with_names
# Out:
#                           PC 1      PC 2      PC 3
# coin_id
# bitcoin              -0.600667  0.842760  0.461595
# ethereum             -0.458261  0.458466  0.952877
# tether               -0.433070 -0.168126 -0.641752
# ripple               -0.471835 -0.222660 -0.479053
# bitcoin-cash         -1.157800  2.041209  1.859715
# binancecoin          -0.516534  1.388377  0.804071
# chainlink            -0.450711  0.517699  2.846143
# cardano              -0.345600  0.729439  1.478013
# litecoin             -0.649468  0.432165  0.600303
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653
# crypto-com-chain     -0.248198 -1.376252 -1.462026
# usd-coin             -0.438408 -0.175337 -0.663388
# eos                  -0.693425 -0.473815 -0.527597
# monero                0.060499  2.909404  1.498571
# tron                 -0.393352 -0.108192 -0.012756
# tezos                -0.796176 -0.494409  1.082812
# okb                   0.064075 -1.269825 -1.098829
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia_list = []

# Create a for loop to compute the inertia with each possible value of k
for k in k_values:
    # Inside the loop:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=0)
    
    # 2. Fit the model to the data using `df_market_data_pca`
    kmeans.fit(df_pca_with_names)
    
    # 3. Append the model.inertia_ to the inertia list
    inertia_list.append(kmeans.inertia_)
# Out:
# C:\Users\rwhit\anaconda3\envs\dev\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   "KMeans is known to have a memory leak on Windows "

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {'k': k_values, 'inertia': inertia_list}

# Create a DataFrame with the data to plot the Elbow curve
df_elbow2 = pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_plot = df_elbow2.hvplot.line(x='k', y='inertia', title='Elbow Curve', xticks=k_values)

elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** It does not differ from the k value found using the original data.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
k_value = 4
kmeans = KMeans(n_clusters=k_value, random_state=0)

# %%
# Fit the K-Means model using the PCA data
kmeans.fit(df_pca_with_names)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
clusters = kmeans.predict(df_pca_with_names)

# Print the resulting array of cluster values.
clusters
# Out:
# array([0, 0, 3, 3, 0, 0, 0, 0, 0, 3, 3, 3, 3, 0, 3, 0, 3, 3, 0, 3, 3, 0,
#        3, 3, 3, 3, 3, 3, 0, 3, 3, 3, 1, 0, 3, 3, 2, 3, 3, 3, 3])

# %%
# Create a copy of the DataFrame with the PCA data
df_pca_clustered = df_pca_with_names.copy()

# Add a new column to the DataFrame with the predicted clusters
df_pca_clustered['cluster'] = clusters

# Display sample data
df_pca_clustered
# Out:
#                           PC 1      PC 2      PC 3  cluster
# coin_id
# bitcoin              -0.600667  0.842760  0.461595        0
# ethereum             -0.458261  0.458466  0.952877        0
# tether               -0.433070 -0.168126 -0.641752        3
# ripple               -0.471835 -0.222660 -0.479053        3
# bitcoin-cash         -1.157800  2.041209  1.859715        0
# binancecoin          -0.516534  1.388377  0.804071        0
# chainlink            -0.450711  0.517699  2.846143        0
# cardano              -0.345600  0.729439  1.478013        0
# litecoin             -0.649468  0.432165  0.600303        0
# bitcoin-cash-sv      -0.759014 -0.201200 -0.217653        3
# crypto-com-chain     -0.248198 -1.376252 -1.462026        3
# usd-coin             -0.438408 -0.175337 -0.663388        3
# eos                  -0.693425 -0.473815 -0.527597        3
# monero                0.060499  2.909404  1.498571        0
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
scatter_plot2 = df_pca_clustered.hvplot.scatter(
    x='PC 1', 
    y='PC 2', 
    by='cluster', 
    hover_cols=['coin_id'], 
    title='Cryptocurrency Clusters in PCA Space'
)

scatter_plot2
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [PC 1]   (PC 2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
elbow_plot1 = df_elbow1.hvplot.line(x='k', y='inertia', title='Elbow Curve 1')
elbow_plot2 = df_elbow2.hvplot.line(x='k', y='inertia', title='Elbow Curve 2')

elbow_plot1
elbow_plot2
# Out:
# :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
composite_elbow_plot = elbow_plot1 + elbow_plot2
composite_cluster_plot = scatter_plot1 + scatter_plot2

composite_elbow_plot
composite_cluster_plot
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster]
#       :Scatter   [PC 1]   (PC 2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** Cluster Separation: In the PCA space (second image), the clusters appear to be more clearly separated compared to the original feature space (first image). This suggests that PCA may have successfully captured the variance in the data that best separates the clusters.
#
# Dimensionality Reduction: The PCA transformation has reduced the dimensionality of the data while retaining the features that contribute most to its variance. This often enhances clustering performance because it reduces noise and less relevant information.
#
# Interpretability: The clusters in the PCA space might be less interpretable in terms of original features since PCA components are linear combinations of the input features. The original feature space provides direct insights into how the features relate to the clusters.
#
# Outliers: Both plots show some potential outliers (data points that are far from the others). In the PCA plot, these outliers are even more pronounced, which could either indicate that PCA has effectively captured extreme variations in the data or that it has amplified the effect of outliers.
#
# Cluster Distribution: The distribution of clusters in the PCA space seems to be more compact for some clusters, suggesting that PCA may have condensed the variance effectively for those groups.
#
# Cluster Overlap: In the first plot, there appears to be more overlap between clusters, especially between clusters 0 and 3. In contrast, the PCA plot shows a clearer distinction, indicating that PCA may be providing a better separation of clusters.
#
# Overall, using fewer features through PCA seems to result in clearer cluster separation, potentially improving the clustering results. However, one must consider the trade-offs in interpretability, as the PCA components do not correspond directly to the original features. Additionally, the effect of outliers and the ability to generalize beyond the dataset should be considered when evaluating the impact of using PCA for clustering with K-Means.
